# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Copy of ECN000321Nov.csv")

# %%
df.columns
# Out:
# Index(['id', 'val', 'Node', 'Channel', 'Value', 'is_posted', 'create_ts',
#        'sent_ts', 'State ', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
       'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15'],inplace=True)

# %%
df.head(50)
# Out:
#          id         val       Node Channel  Value  is_posted  \
# 0   4403892  1603285199   EC4N0003      A0   0.10          0
# 1   4403893  1603285199   EC4N0003      A1   0.11          0
# 2   4403894  1603285199   EC4N0003      A2   0.15          0
# 3   4403903  1603285200   EC4N0003      A1   0.14          0
# 4   4403904  1603285200   EC4N0003      A2   0.14          0
# 5   4403918  1603285201   EC4N0003      A1   0.12          0
# 6   4403919  1603285201   EC4N0003      A2   0.13          0
# 7   4403920  1603285201   EC4N0003      A0   0.09          0
# 8   4403929  1603285202   EC4N0003      A2   0.15          0
# 9   4403930  1603285202   EC4N0003      A0   0.12          0
# 10  4403931  1603285202   EC4N0003      A1   0.11          0
# 11  4403940  1603285203   EC4N0003      A0   0.10          0
# 12  4403941  1603285203   EC4N0003      A1   0.12          0
# 13  4403951  1603285204   EC4N0003      A0   0.13          0
# ...

# %%
df.dtypes
# Out:
# id             int64
# val            int64
# Node          object
# Channel       object
# Value        float64
# is_posted      int64
# create_ts     object
# sent_ts      float64
# State         object
# dtype: object

# %%
df['create_ts'] = df['create_ts'].astype('datetime64[ns]')

# %%
df.dtypes
# Out:
# id                    int64
# val                   int64
# Node                 object
# Channel              object
# Value               float64
# is_posted             int64
# create_ts    datetime64[ns]
# sent_ts             float64
# State                object
# dtype: object

# %%
figsize=(10,10)
df.plot(x="create_ts",y="Value")

# %%
df['rolling_avg'] = df['Value'].rolling(window=4).mean()

# %%
df['rolling_avg']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3        0.1250
# 4        0.1350
#           ...
# 27195    0.1300
# 27196    0.1300
# 27197    0.1325
# 27198    0.1325
# 27199    0.1225
# Name: rolling_avg, Length: 27200, dtype: float64

# %%
df.dtypes
# Out:
# id                      int64
# val                     int64
# Node                   object
# Channel                object
# Value                 float64
# is_posted               int64
# create_ts      datetime64[ns]
# sent_ts               float64
# State                  object
# rolling_avg           float64
# dtype: object

# %%
df.describe()
# Out:
#                  id           val         Value  is_posted       sent_ts  \
# count  2.720000e+04  2.720000e+04  27200.000000    27200.0  27200.000000
# mean   4.462193e+06  1.603291e+09      0.393945        0.0     -0.000004
# std    3.366612e+04  3.111728e+03      0.795025        0.0      0.338943
# min    4.403892e+06  1.603285e+09      0.080000        0.0    -20.860000
# 25%    4.433030e+06  1.603288e+09      0.110000        0.0     -0.030000
# 50%    4.461992e+06  1.603291e+09      0.120000        0.0      0.000000
# 75%    4.491375e+06  1.603293e+09      0.150000        0.0      0.030000
# max    4.520714e+06  1.603296e+09     23.350000        0.0     23.240000
#
#         rolling_avg
# count  27197.000000
# mean       0.393976
# std        0.766738
# min        0.097500
# 25%        0.120000
# 50%        0.127500
# 75%        0.132500
# max        7.897500

# %%
df['pred'] = np.where(df['rolling_avg']>=1, 'Running', 'Idle')

# %%
df.head(50)
# Out:
#          id         val       Node Channel  Value  is_posted  \
# 0   4403892  1603285199   EC4N0003      A0   0.10          0
# 1   4403893  1603285199   EC4N0003      A1   0.11          0
# 2   4403894  1603285199   EC4N0003      A2   0.15          0
# 3   4403903  1603285200   EC4N0003      A1   0.14          0
# 4   4403904  1603285200   EC4N0003      A2   0.14          0
# 5   4403918  1603285201   EC4N0003      A1   0.12          0
# 6   4403919  1603285201   EC4N0003      A2   0.13          0
# 7   4403920  1603285201   EC4N0003      A0   0.09          0
# 8   4403929  1603285202   EC4N0003      A2   0.15          0
# 9   4403930  1603285202   EC4N0003      A0   0.12          0
# 10  4403931  1603285202   EC4N0003      A1   0.11          0
# 11  4403940  1603285203   EC4N0003      A0   0.10          0
# 12  4403941  1603285203   EC4N0003      A1   0.12          0
# 13  4403951  1603285204   EC4N0003      A0   0.13          0
# ...

# %%
df.to_csv('file1.csv')
